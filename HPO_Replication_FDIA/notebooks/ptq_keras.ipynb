# %% [markdown]
# #  Imports

# %%
import keras
import numpy as np
import os

from sklearn.metrics import (
    accuracy_score,
    balanced_accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    confusion_matrix,
    classification_report
)

print("Keras:", keras.__version__)

# %%
import pathlib

MODELS_DIR = pathlib.Path("../models/keras")
RESULTS_DIR = pathlib.Path("../results")

MODEL_PATH = MODELS_DIR / "MLP_HPO.keras"
QUANTIZED_MODEL_PATH = MODELS_DIR / "MLP_HPO_INT8.keras"

RESULTS_DIR.mkdir(exist_ok=True)

print("Original model:", MODEL_PATH.resolve())
print("Quantized model:", QUANTIZED_MODEL_PATH.resolve())
print("\nOriginal model exists:", MODEL_PATH.exists())
